# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA, KernelPCA
from scipy.stats import pearsonr
from sklearn.cluster import KMeans
from yellowbrick.cluster import KElbowVisualizer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer

# %%
df=pd.read_csv('ev_charging_patterns.csv')
df.head()
# Out:
#   User ID Vehicle Model  Battery Capacity (kWh) Charging Station ID  \
# 0  User_1        BMW i3              108.463007         Station_391
# 1  User_2  Hyundai Kona              100.000000         Station_428
# 2  User_3    Chevy Bolt               75.000000         Station_181
# 3  User_4  Hyundai Kona               50.000000         Station_327
# 4  User_5  Hyundai Kona               50.000000         Station_108
#
#   Charging Station Location  Charging Start Time    Charging End Time  \
# 0                   Houston  2024-01-01 00:00:00  2024-01-01 00:39:00
# 1             San Francisco  2024-01-01 01:00:00  2024-01-01 03:01:00
# 2             San Francisco  2024-01-01 02:00:00  2024-01-01 04:48:00
# 3                   Houston  2024-01-01 03:00:00  2024-01-01 06:42:00
# 4               Los Angeles  2024-01-01 04:00:00  2024-01-01 05:46:00
#
#    Energy Consumed (kWh)  Charging Duration (hours)  Charging Rate (kW)  \
# 0              60.712346                   0.591363           36.389181
# 1              12.339275                   3.133652           30.677735
# 2              19.128876                   2.452653           27.513593
# 3              79.457824                   1.266431           32.882870
# 4              19.629104                   2.019765           10.215712
#
#    Charging Cost (USD) Time of Day Day of Week  State of Charge (Start %)  \
# 0            13.087717     Evening     Tuesday                  29.371576
# 1            21.128448     Morning      Monday                  10.115778
# 2            35.667270     Morning    Thursday                   6.854604
# 3            13.036239     Evening    Saturday                  83.120003
# 4            10.161471     Morning    Saturday                  54.258950
#
#    State of Charge (End %)  Distance Driven (since last charge) (km)  \
# 0                86.119962                                293.602111
# 1                84.664344                                112.112804
# 2                69.917615                                 71.799253
# 3                99.624328                                199.577785
# 4                63.743786                                203.661847
#
#    Temperature (°C)  Vehicle Age (years)     Charger Type  \
# 0         27.947953                  2.0  DC Fast Charger
# 1         14.311026                  3.0          Level 1
# 2         21.002002                  2.0          Level 2
# 3         38.316313                  1.0          Level 1
# 4         -7.834199                  1.0          Level 1
#
#                 User Type
# 0                Commuter
# 1           Casual Driver
# 2                Commuter
# 3  Long-Distance Traveler
# 4  Long-Distance Traveler

# %%
df.describe()
# Out:
#        Battery Capacity (kWh)  Energy Consumed (kWh)  \
# count             1320.000000            1254.000000
# mean                74.534692              42.642894
# std                 20.626914              22.411705
# min                  1.532807               0.045772
# 25%                 62.000000              23.881193
# 50%                 75.000000              42.691405
# 75%                 85.000000              61.206218
# max                193.003074             152.238758
#
#        Charging Duration (hours)  Charging Rate (kW)  Charging Cost (USD)  \
# count                1320.000000         1254.000000          1320.000000
# mean                    2.269377           25.963003            22.551352
# std                     1.061037           14.011326            10.751494
# min                     0.095314            1.472549             0.234317
# 25%                     1.397623           13.856583            13.368141
# 50%                     2.258136           25.603799            22.076360
# 75%                     3.112806           37.502998            31.646044
# max                     7.635145           97.342255            69.407743
#
#        State of Charge (Start %)  State of Charge (End %)  \
# count                1320.000000              1320.000000
# mean                   49.130012                75.141590
# std                    24.074134                17.080580
# min                     2.325959                 7.604224
# 25%                    27.786903                62.053266
# 50%                    48.241771                75.682496
# 75%                    69.277921                88.201370
# max                   152.489761               177.708666
#
#        Distance Driven (since last charge) (km)  Temperature (°C)  \
# count                               1254.000000       1320.000000
# mean                                 153.596788         15.263591
# std                                   86.004987         14.831216
# min                                    0.862361        -10.724770
# 25%                                   79.445335          2.800664
# 50%                                  152.259867         14.630846
# 75%                                  226.073284         27.981810
# max                                  398.364775         73.169588
#
#        Vehicle Age (years)
# count          1320.000000
# mean              3.612843
# std               2.309824
# min               0.000000
# 25%               2.000000
# 50%               4.000000
# 75%               6.000000
# max              11.688592

# %%
df.isnull().sum()
# Out:
# User ID                                      0
# Vehicle Model                                0
# Battery Capacity (kWh)                       0
# Charging Station ID                          0
# Charging Station Location                    0
# Charging Start Time                          0
# Charging End Time                            0
# Energy Consumed (kWh)                       66
# Charging Duration (hours)                    0
# Charging Rate (kW)                          66
# Charging Cost (USD)                          0
# Time of Day                                  0
# Day of Week                                  0
# State of Charge (Start %)                    0
# State of Charge (End %)                      0
# Distance Driven (since last charge) (km)    66
# Temperature (°C)                             0
# Vehicle Age (years)                          0
# Charger Type                                 0
# User Type                                    0
# dtype: int64

# %%
# Séparation des colonnes catégorielles et numériques
categorical_columns = ['Vehicle Model', 'Charging Station Location', 'Day of Week', 'Charger Type', 'User Type']
numeric_columns = ['Battery Capacity (kWh)', 'Energy Consumed (kWh)', 'Charging Duration (hours)', 
                   'Charging Rate (kW)', 'Charging Cost (USD)', 'Distance Driven (since last charge) (km)', 
                   'Temperature (°C)', 'Vehicle Age (years)', 'State of Charge (Start %)', 'State of Charge (End %)']

# %% [markdown]
# ### Partie Analyse

# %%
# Suppression des colonnes inutiles avant tout traitement
df = df.drop(columns=['User ID', 'Charging Station ID', 'Charging Start Time', 'Charging End Time'])

# %%
cols_numeric=df[numeric_columns]
cols_numeric
# Out:
#       Battery Capacity (kWh)  Energy Consumed (kWh)  \
# 0                 108.463007              60.712346
# 1                 100.000000              12.339275
# 2                  75.000000              19.128876
# 3                  50.000000              79.457824
# 4                  50.000000              19.629104
# ...                      ...                    ...
# 1315              100.000000              42.011654
# 1316              100.000000              68.185853
# 1317              100.000000              18.895102
# 1318               85.000000              13.756252
# 1319              120.447195              63.652570
#
#       Charging Duration (hours)  Charging Rate (kW)  Charging Cost (USD)  \
# 0                      0.591363           36.389181            13.087717
# 1                      3.133652           30.677735            21.128448
# 2                      2.452653           27.513593            35.667270
# 3                      1.266431           32.882870            13.036239
# 4                      2.019765           10.215712            10.161471
# ...                         ...                 ...                  ...
# 1315                   1.426444            5.895475            22.081164
# 1316                   3.238212           18.388012             5.067806
# 1317                   3.267122           45.482066            37.255002
# 1318                   2.754527           38.148183            39.046146
# 1319                   3.740970           33.704226            10.863674
#
#       Distance Driven (since last charge) (km)  Temperature (°C)  \
# 0                                   293.602111         27.947953
# 1                                   112.112804         14.311026
# 2                                    71.799253         21.002002
# 3                                   199.577785         38.316313
# 4                                   203.661847         -7.834199
# ...                                        ...               ...
# 1315                                239.601075          1.919655
# 1316                                164.376022         34.029775
# 1317                                226.519258         20.358761
# 1318                                291.494076         24.134598
# 1319                                 14.449236         -6.966593
#
#       Vehicle Age (years)  State of Charge (Start %)  State of Charge (End %)
# 0                     2.0                  29.371576                86.119962
# 1                     3.0                  10.115778                84.664344
# 2                     2.0                   6.854604                69.917615
# 3                     1.0                  83.120003                99.624328
# 4                     1.0                  54.258950                63.743786
# ...                   ...                        ...                      ...
# 1315                  7.0                  39.204102                83.915952
# 1316                  4.0                  31.456375                93.096461
# 1317                  5.0                  71.903081                78.678879
# 1318                  5.0                  76.187997                65.926573
# 1319                  5.0                  59.338076                56.692439
#
# [1320 rows x 10 columns]

# %%
# Liste des colonnes pour lesquelles on veut créer les boxplots
cols = [
    'Battery Capacity (kWh)', 
    'Energy Consumed (kWh)', 
    'Charging Duration (hours)', 
    'Charging Rate (kW)', 
    'Charging Cost (USD)', 
    'Distance Driven (since last charge) (km)',
    'Vehicle Age (years)'
]

# Définir la taille de la figure pour afficher plusieurs plots
plt.figure(figsize=(15, 8))

# Boucle sur chaque colonne dans la liste des colonnes à visualiser
for i, col in enumerate(cols):
    plt.subplot(2, 4, i + 1)  # Créer un subplot avec 2 lignes et 3 colonnes
    sns.boxplot(data=df[col])  # Créer le boxplot pour la colonne
    plt.title(f'Boxplot de {col}')  # Ajouter un titre pour chaque boxplot

# Ajuster l'espacement entre les plots
plt.tight_layout()
plt.show()

# %% [markdown]
# ### D'après les boxplots nous constatons les colonnes qui contiennent des valeur aberrantes (' 'Battery Capacity (kWh)',
#     'Energy Consumed (kWh)',
#     'Charging Duration (hours)',
#     'Charging Rate (kW)',
#     'Charging Cost (USD)',
#     'Battery Capacity (kWh)'

# %% [markdown]
# ### traitons les

# %%
import pandas as pd

# Fonction pour détecter les outliers en utilisant l'IQR (Interquartile Range)
def detect_and_replace_outliers_iqr(data, column):
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Calculer la moyenne de la colonne
    mean_value = data[column].mean()

    # Remplacer les outliers par la moyenne
    data[column] = data[column].apply(lambda x: mean_value if x < lower_bound or x > upper_bound else x)

# Liste des colonnes où tu veux détecter et remplacer les outliers
cols = [
    'Battery Capacity (kWh)', 
    'Energy Consumed (kWh)', 
    'Charging Duration (hours)', 
    'Charging Rate (kW)', 
    'Charging Cost (USD)', 
]

# Appliquer la détection et remplacement des outliers pour chaque colonne
for col in cols:
    detect_and_replace_outliers_iqr(df, col)

# Afficher le DataFrame pour vérifier que les outliers ont bien été remplacés
print(df.head())
# Out:
#   Vehicle Model  Battery Capacity (kWh) Charging Station Location  \
# 0        BMW i3              108.463007                   Houston
# 1  Hyundai Kona              100.000000             San Francisco
# 2    Chevy Bolt               75.000000             San Francisco
# 3  Hyundai Kona               50.000000                   Houston
# 4  Hyundai Kona               50.000000               Los Angeles
#
#    Energy Consumed (kWh)  Charging Duration (hours)  Charging Rate (kW)  \
# 0              60.712346                   0.591363           36.389181
# 1              12.339275                   3.133652           30.677735
# 2              19.128876                   2.452653           27.513593
# 3              79.457824                   1.266431           32.882870
# 4              19.629104                   2.019765           10.215712
#
#    Charging Cost (USD) Time of Day Day of Week  State of Charge (Start %)  \
# 0            13.087717     Evening     Tuesday                  29.371576
# 1            21.128448     Morning      Monday                  10.115778
# 2            35.667270     Morning    Thursday                   6.854604
# 3            13.036239     Evening    Saturday                  83.120003
# 4            10.161471     Morning    Saturday                  54.258950
#
#    State of Charge (End %)  Distance Driven (since last charge) (km)  \
# 0                86.119962                                293.602111
# 1                84.664344                                112.112804
# 2                69.917615                                 71.799253
# 3                99.624328                                199.577785
# 4                63.743786                                203.661847
#
#    Temperature (°C)  Vehicle Age (years)     Charger Type  \
# 0         27.947953                  2.0  DC Fast Charger
# 1         14.311026                  3.0          Level 1
# 2         21.002002                  2.0          Level 2
# 3         38.316313                  1.0          Level 1
# 4         -7.834199                  1.0          Level 1
#
#                 User Type
# 0                Commuter
# 1           Casual Driver
# 2                Commuter
# 3  Long-Distance Traveler
# 4  Long-Distance Traveler

# %%
df.head()
# Out:
#   Vehicle Model  Battery Capacity (kWh) Charging Station Location  \
# 0        BMW i3              108.463007                   Houston
# 1  Hyundai Kona              100.000000             San Francisco
# 2    Chevy Bolt               75.000000             San Francisco
# 3  Hyundai Kona               50.000000                   Houston
# 4  Hyundai Kona               50.000000               Los Angeles
#
#    Energy Consumed (kWh)  Charging Duration (hours)  Charging Rate (kW)  \
# 0              60.712346                   0.591363           36.389181
# 1              12.339275                   3.133652           30.677735
# 2              19.128876                   2.452653           27.513593
# 3              79.457824                   1.266431           32.882870
# 4              19.629104                   2.019765           10.215712
#
#    Charging Cost (USD) Time of Day Day of Week  State of Charge (Start %)  \
# 0            13.087717     Evening     Tuesday                  29.371576
# 1            21.128448     Morning      Monday                  10.115778
# 2            35.667270     Morning    Thursday                   6.854604
# 3            13.036239     Evening    Saturday                  83.120003
# 4            10.161471     Morning    Saturday                  54.258950
#
#    State of Charge (End %)  Distance Driven (since last charge) (km)  \
# 0                86.119962                                293.602111
# 1                84.664344                                112.112804
# 2                69.917615                                 71.799253
# 3                99.624328                                199.577785
# 4                63.743786                                203.661847
#
#    Temperature (°C)  Vehicle Age (years)     Charger Type  \
# 0         27.947953                  2.0  DC Fast Charger
# 1         14.311026                  3.0          Level 1
# 2         21.002002                  2.0          Level 2
# 3         38.316313                  1.0          Level 1
# 4         -7.834199                  1.0          Level 1
#
#                 User Type
# 0                Commuter
# 1           Casual Driver
# 2                Commuter
# 3  Long-Distance Traveler
# 4  Long-Distance Traveler

# %% [markdown]
# ### Verifions de nouveaux les outliers

# %%
# Liste des colonnes pour lesquelles on veut créer les boxplots
cols = [
    'Battery Capacity (kWh)', 
    'Energy Consumed (kWh)', 
    'Charging Duration (hours)', 
    'Charging Rate (kW)', 
    'Charging Cost (USD)', 
    'Distance Driven (since last charge) (km)',
    'Vehicle Age (years)'
]

# Définir la taille de la figure pour afficher plusieurs plots
plt.figure(figsize=(15, 8))

# Boucle sur chaque colonne dans la liste des colonnes à visualiser
for i, col in enumerate(cols):
    plt.subplot(2, 4, i + 1)  # Créer un subplot avec 2 lignes et 3 colonnes
    sns.boxplot(data=df[col])  # Créer le boxplot pour la colonne
    plt.title(f'Boxplot de {col}')  # Ajouter un titre pour chaque boxplot

# Ajuster l'espacement entre les plots
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Parfait

# %%
### Maintenant passons au prétraitement des valeurs manquantes et la normalisation en utilisant un pipeline

# %%
# Séparation des colonnes catégorielles et numériques
categorical_columns = ['Vehicle Model', 'Charging Station Location', 'Day of Week', 'Charger Type', 'User Type']
numeric_columns = ['Battery Capacity (kWh)', 'Energy Consumed (kWh)', 'Charging Duration (hours)', 
                   'Charging Rate (kW)', 'Charging Cost (USD)', 'Distance Driven (since last charge) (km)', 
                   'Temperature (°C)', 'Vehicle Age (years)', 'State of Charge (Start %)', 'State of Charge (End %)']

# %%
# Création d'un transformateur pour les variables numériques (imputation + standardisation)
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')),  # Imputation des valeurs manquantes par la moyenne
    ('scaler', StandardScaler())                 # Standardisation
])

# %%
# Création d'un transformateur pour les variables catégorielles (encodage + imputation si nécessaire)
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),  # Pour les valeurs manquantes, on utilise la valeur la plus fréquente
    ('onehot', OneHotEncoder(handle_unknown='ignore'))     # One-Hot Encoding
])

# %%
# Application des transformations via ColumnTransformer
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_columns),
        ('cat', categorical_transformer, categorical_columns)
    ])

# %%
# Création du pipeline global de prétraitement
preprocessing_pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor)
])

# %%
# Application du pipeline sur les données
df_preprocessed = preprocessing_pipeline.fit_transform(df)

# Vérification du résultat
print(df_preprocessed.shape)  # Affiche les dimensions des données prétraitées
# Out:
# (1320, 33)

# %%
print(df_preprocessed)
# Out:
# [[ 1.95265193  0.84772648 -1.62851194 ...  0.          1.
#    0.        ]
#  [ 1.4680119  -1.40235617  0.86827457 ...  1.          0.
#    0.        ]
#  [ 0.03636946 -1.0865366   0.19946383 ...  0.          1.
#    0.        ]
#  ...
#  [ 1.4680119  -1.09741064  0.99935536 ...  0.          1.
#    0.        ]
#  [ 0.60902644 -1.33644525  0.4959356  ...  0.          1.
#    0.        ]
#  [ 0.00972326  0.98449159  1.46472304 ...  0.          1.
#    0.        ]]

# %%
# Sauvegarde du tableau numpy
np.save('data.npy', df_preprocessed)

# %%
# Aplication de l'ACP (2 composante)
pca=PCA(n_components=2)
res_pca=pca.fit_transform(df_preprocessed)
type(res_pca)
# Out:
# numpy.ndarray

# %%
res_pca
# Out:
# array([[-1.25832563, -1.19315263],
#        [-1.33418629, -0.88119787],
#        [ 0.23446873, -1.18989054],
#        ...,
#        [ 0.49842187, -1.27377632],
#        [ 1.17989737, -1.50842027],
#        [-0.80881447,  1.32940324]])

# %%
# Visualisation des composantes principales

plt.scatter(res_pca[:,0], res_pca[:,1])
plt.xlabel("Composante 1")
plt.ylabel("Composante 2")
plt.title("PC1 vs PC2")
plt.show()

# %%
# Coefficient de correlation de pearson obtenu après ACP
pearsonr(res_pca[:, 0], res_pca[:, 1])
# Out:
# PearsonRResult(statistic=-7.914675859144182e-18, pvalue=0.9999999999996411)

# %% [markdown]
# ### ACP non linéaire

# %%
# Chargement de données d'entrainement recement sauvegarder
data=np.load('data.npy')

# %%
# KPCA avec noyau ''rbf''
kpca=KernelPCA(n_components=2, kernel='rbf')
res_kpca_rbf=kpca.fit_transform(data)
type(res_kpca_rbf)
# Out:
# numpy.ndarray

# %%
res_kpca_rbf
# Out:
# array([[-0.08488252,  0.24486377],
#        [-0.13183879,  0.28720037],
#        [ 0.11999467,  0.2254509 ],
#        ...,
#        [ 0.15279134,  0.19624523],
#        [ 0.25762591,  0.17179464],
#        [-0.24155501, -0.14434209]])

# %%
# Visualisation des composantes principales

plt.scatter(res_kpca_rbf[:,0], res_kpca_rbf[:,1])
plt.xlabel("Composante 1")
plt.ylabel("Composante 2")
plt.title("PC1 vs PC2")
plt.show()

# %%
# Coefficient de correlation de pearson obtenu après ACP
pearsonr(res_kpca_rbf[:, 0], res_kpca_rbf[:, 1])
# Out:
# PearsonRResult(statistic=-2.4448758989548125e-16, pvalue=0.9999999999995767)

# %%
#Comparaison des coefficient de pearson
pearsonr(res_kpca_rbf[:, 0], res_kpca_rbf[:, 1])[0]<pearsonr(res_pca[:, 0], res_pca[:, 1])[0]
# Out:
# True

# %% [markdown]
# ### Selon la comparaison on peut dire que les deux composants sont plus correler avec l'ACP non lineaire qu'avec l'ACP lineaire

# %%
# Ajout des composantes principales comme colonnes de df
df['x_kpc_rbf']=res_kpca_rbf[:,0]
df['y_kpc_rbf']=res_kpca_rbf[:,1]
df.head()
# Out:
#   Vehicle Model  Battery Capacity (kWh) Charging Station Location  \
# 0        BMW i3              108.463007                   Houston
# 1  Hyundai Kona              100.000000             San Francisco
# 2    Chevy Bolt               75.000000             San Francisco
# 3  Hyundai Kona               50.000000                   Houston
# 4  Hyundai Kona               50.000000               Los Angeles
#
#    Energy Consumed (kWh)  Charging Duration (hours)  Charging Rate (kW)  \
# 0              60.712346                   0.591363           36.389181
# 1              12.339275                   3.133652           30.677735
# 2              19.128876                   2.452653           27.513593
# 3              79.457824                   1.266431           32.882870
# 4              19.629104                   2.019765           10.215712
#
#    Charging Cost (USD) Time of Day Day of Week  State of Charge (Start %)  \
# 0            13.087717     Evening     Tuesday                  29.371576
# 1            21.128448     Morning      Monday                  10.115778
# 2            35.667270     Morning    Thursday                   6.854604
# 3            13.036239     Evening    Saturday                  83.120003
# 4            10.161471     Morning    Saturday                  54.258950
#
#    State of Charge (End %)  Distance Driven (since last charge) (km)  \
# 0                86.119962                                293.602111
# 1                84.664344                                112.112804
# 2                69.917615                                 71.799253
# 3                99.624328                                199.577785
# 4                63.743786                                203.661847
#
#    Temperature (°C)  Vehicle Age (years)     Charger Type  \
# 0         27.947953                  2.0  DC Fast Charger
# 1         14.311026                  3.0          Level 1
# 2         21.002002                  2.0          Level 2
# 3         38.316313                  1.0          Level 1
# 4         -7.834199                  1.0          Level 1
#
#                 User Type  x_kpc_rbf  y_kpc_rbf
# 0                Commuter  -0.084883   0.244864
# 1           Casual Driver  -0.131839   0.287200
# 2                Commuter   0.119995   0.225451
# 3  Long-Distance Traveler   0.106192  -0.149172
# 4  Long-Distance Traveler  -0.075216   0.040006

# %% [markdown]
# ## Le Clustering K-Means avec la méthode du coude

# %%
# Clustering avec 5 clusters
cluster_model=KMeans(n_clusters=4)
cluster_model.fit(res_kpca_rbf)
clusters=cluster_model.predict(res_kpca_rbf)
# Out:
# C:\Users\MHD\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
# Affichage des clusters
clusters
# Out:
# array([1, 1, 1, ..., 3, 3, 2])

# %%
#Visualisons les clusters

plt.scatter(res_kpca_rbf[:,0], res_kpca_rbf[:,1],c=clusters)
plt.xlabel("Composante 1")
plt.ylabel("Composante 2")
plt.title("PC1 vs PC2")
plt.show()

# %%
# Methode du coude  pour savoir la meilleure K
kmeans=KMeans()
visualizer=KElbowVisualizer(kmeans, k=(2,12))
visualizer.fit(res_kpca_rbf)
visualizer.show()
# Out:
# C:\Users\MHD\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\MHD\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\MHD\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\MHD\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\MHD\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\MHD\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\MHD\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\MHD\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\MHD\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\MHD\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# <Axes: title={'center': 'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %%
# Ajout des clusters à df et sauvegardons au format CSV
df['cluster_kpca_rbf']=clusters
df.to_csv('data_with_clusters.csv')

# %% [markdown]
# ### Passons mainteneant à l'analyse des résultats des segmentations

# %%
# Chargement des données 
df=pd.read_csv('data_with_clusters.csv', index_col=0)
df.head()
# Out:
#   Vehicle Model  Battery Capacity (kWh) Charging Station Location  \
# 0        BMW i3              108.463007                   Houston
# 1  Hyundai Kona              100.000000             San Francisco
# 2    Chevy Bolt               75.000000             San Francisco
# 3  Hyundai Kona               50.000000                   Houston
# 4  Hyundai Kona               50.000000               Los Angeles
#
#    Energy Consumed (kWh)  Charging Duration (hours)  Charging Rate (kW)  \
# 0              60.712346                   0.591363           36.389181
# 1              12.339275                   3.133652           30.677735
# 2              19.128876                   2.452653           27.513593
# 3              79.457824                   1.266431           32.882870
# 4              19.629104                   2.019765           10.215712
#
#    Charging Cost (USD) Time of Day Day of Week  State of Charge (Start %)  \
# 0            13.087717     Evening     Tuesday                  29.371576
# 1            21.128448     Morning      Monday                  10.115778
# 2            35.667270     Morning    Thursday                   6.854604
# 3            13.036239     Evening    Saturday                  83.120003
# 4            10.161471     Morning    Saturday                  54.258950
#
#    State of Charge (End %)  Distance Driven (since last charge) (km)  \
# 0                86.119962                                293.602111
# 1                84.664344                                112.112804
# 2                69.917615                                 71.799253
# 3                99.624328                                199.577785
# 4                63.743786                                203.661847
#
#    Temperature (°C)  Vehicle Age (years)     Charger Type  \
# 0         27.947953                  2.0  DC Fast Charger
# 1         14.311026                  3.0          Level 1
# 2         21.002002                  2.0          Level 2
# 3         38.316313                  1.0          Level 1
# 4         -7.834199                  1.0          Level 1
#
#                 User Type  x_kpc_rbf  y_kpc_rbf  cluster_kpca_rbf
# 0                Commuter  -0.084883   0.244864                 1
# 1           Casual Driver  -0.131839   0.287200                 1
# 2                Commuter   0.119995   0.225451                 1
# 3  Long-Distance Traveler   0.106192  -0.149172                 0
# 4  Long-Distance Traveler  -0.075216   0.040006                 1

# %%
df['cluster_kpca_rbf'].unique()
# Out:
# array([1, 0, 3, 2], dtype=int64)

# %%
#Stockage des noms des colonnes dans une liste
features=df.columns.tolist()
features
# Out:
# ['Vehicle Model',
#  'Battery Capacity (kWh)',
#  'Charging Station Location',
#  'Energy Consumed (kWh)',
#  'Charging Duration (hours)',
#  'Charging Rate (kW)',
#  'Charging Cost (USD)',
#  'Time of Day',
#  'Day of Week',
#  'State of Charge (Start %)',
#  'State of Charge (End %)',
#  'Distance Driven (since last charge) (km)',
#  'Temperature (°C)',
#  'Vehicle Age (years)',
#  'Charger Type',
#  'User Type',
#  'x_kpc_rbf',
#  'y_kpc_rbf',
#  'cluster_kpca_rbf']

# %%
# Centroides
df.groupby('cluster_kpca_rbf')[features].mean()
# Out:
# C:\Users\MHD\AppData\Local\Temp\ipykernel_9500\842859591.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('cluster_kpca_rbf')[features].mean()
#                   Battery Capacity (kWh)  Energy Consumed (kWh)  \
# cluster_kpca_rbf
# 0                              68.749831              50.044226
# 1                              81.491659              33.921580
# 2                              76.217298              56.688534
# 3                              70.436917              30.186941
#
#                   Charging Duration (hours)  Charging Rate (kW)  \
# cluster_kpca_rbf
# 0                                  2.208894           18.590599
# 1                                  2.241594           33.249381
# 2                                  2.800138           21.109402
# 3                                  1.774753           30.089289
#
#                   Charging Cost (USD)  State of Charge (Start %)  \
# cluster_kpca_rbf
# 0                           23.093569                  63.602515
# 1                           21.721490                  35.915646
# 2                           16.523116                  41.615663
# 3                           28.285718                  55.941114
#
#                   State of Charge (End %)  \
# cluster_kpca_rbf
# 0                               76.230163
# 1                               74.878430
# 2                               79.432770
# 3                               70.155798
#
#                   Distance Driven (since last charge) (km)  Temperature (°C)  \
# cluster_kpca_rbf
# 0                                               117.970313         20.575731
# 1                                               187.421103         10.012440
# 2                                               155.210441          6.396223
# 3                                               152.142670         24.082594
#
#                   Vehicle Age (years)  x_kpc_rbf  y_kpc_rbf  cluster_kpca_rbf
# cluster_kpca_rbf
# 0                            4.724636   0.053227  -0.182648               0.0
# 1                            2.676494  -0.049202   0.177806               1.0
# 2                            4.082395  -0.203216  -0.060303               2.0
# 3                            3.041670   0.194077   0.050058               3.0

# %%
df.groupby(['cluster_kpca_rbf', 'Vehicle Model'])[features].mean()
# Out:
# C:\Users\MHD\AppData\Local\Temp\ipykernel_9500\1100084770.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['cluster_kpca_rbf', 'Vehicle Model'])[features].mean()
#                                 Battery Capacity (kWh)  Energy Consumed (kWh)  \
# cluster_kpca_rbf Vehicle Model
# 0                BMW i3                      68.458696              45.513166
#                  Chevy Bolt                  69.792936              47.834511
#                  Hyundai Kona                67.760083              53.570753
#                  Nissan Leaf                 70.372992              50.520472
#                  Tesla Model 3               67.799101              52.340049
# 1                BMW i3                      82.012425              32.464502
#                  Chevy Bolt                  78.333101              33.078503
#                  Hyundai Kona                83.488320              32.924828
#                  Nissan Leaf                 79.385008              36.368584
#                  Tesla Model 3               84.079335              35.304170
# 2                BMW i3                      77.150638              56.816691
#                  Chevy Bolt                  76.456285              54.881648
#                  Hyundai Kona                79.607789              58.181622
#                  Nissan Leaf                 76.066738              57.379948
#                  Tesla Model 3               73.010982              56.681996
# 3                BMW i3                      76.202591              29.968268
#                  Chevy Bolt                  70.773037              26.005453
#                  Hyundai Kona                69.017983              33.201573
#                  Nissan Leaf                 68.339645              31.692761
#                  Tesla Model 3               70.055906              28.278443
#
#                                 Charging Duration (hours)  Charging Rate (kW)  \
# cluster_kpca_rbf Vehicle Model
# 0                BMW i3                          2.204785           19.817404
#                  Chevy Bolt                      2.422006           16.924885
#                  Hyundai Kona                    2.274309           18.368081
#                  Nissan Leaf                     1.972307           20.261888
#                  Tesla Model 3                   2.173024           17.809388
# 1                BMW i3                          2.103679           34.575073
#                  Chevy Bolt                      2.351655           32.476466
#                  Hyundai Kona                    2.242433           32.149131
#                  Nissan Leaf                     2.231303           33.182660
#                  Tesla Model 3                   2.266366           33.939819
# 2                BMW i3                          2.565353           23.056276
#                  Chevy Bolt                      2.910314           19.101281
#                  Hyundai Kona                    3.010458           22.263897
#                  Nissan Leaf                     2.755299           20.074453
#                  Tesla Model 3                   2.837363           21.150930
# 3                BMW i3                          1.654899           28.979178
#                  Chevy Bolt                      2.026247           29.318793
#                  Hyundai Kona                    1.840078           31.583093
#                  Nissan Leaf                     1.717882           30.918191
#                  Tesla Model 3                   1.642674           28.751405
#
#                                 Charging Cost (USD)  \
# cluster_kpca_rbf Vehicle Model
# 0                BMW i3                   23.124396
#                  Chevy Bolt               24.094010
#                  Hyundai Kona             21.934686
#                  Nissan Leaf              24.305901
#                  Tesla Model 3            22.381255
# 1                BMW i3                   18.496762
#                  Chevy Bolt               21.288257
#                  Hyundai Kona             21.762680
#                  Nissan Leaf              24.639382
#                  Tesla Model 3            22.849230
# 2                BMW i3                   15.189809
#                  Chevy Bolt               16.940714
#                  Hyundai Kona             18.457317
#                  Nissan Leaf              14.873660
#                  Tesla Model 3            17.539136
# 3                BMW i3                   29.043495
#                  Chevy Bolt               27.737591
#                  Hyundai Kona             28.662317
#                  Nissan Leaf              28.364889
#                  Tesla Model 3            27.614010
#
#                                 State of Charge (Start %)  \
# cluster_kpca_rbf Vehicle Model
# 0                BMW i3                         68.770762
#                  Chevy Bolt                     64.936650
#                  Hyundai Kona                   63.124785
#                  Nissan Leaf                    61.165772
#                  Tesla Model 3                  60.390196
# 1                BMW i3                         37.332618
#                  Chevy Bolt                     36.405307
#                  Hyundai Kona                   38.305501
#                  Nissan Leaf                    31.001553
#                  Tesla Model 3                  35.640985
# 2                BMW i3                         40.465930
#                  Chevy Bolt                     44.311496
#                  Hyundai Kona                   41.442482
#                  Nissan Leaf                    40.952222
#                  Tesla Model 3                  41.010263
# 3                BMW i3                         55.367675
#                  Chevy Bolt                     56.825659
#                  Hyundai Kona                   56.646467
#                  Nissan Leaf                    56.190780
#                  Tesla Model 3                  54.420302
#
#                                 State of Charge (End %)  \
# cluster_kpca_rbf Vehicle Model
# 0                BMW i3                       72.636088
#                  Chevy Bolt                   76.580263
#                  Hyundai Kona                 77.430783
#                  Nissan Leaf                  78.666333
#                  Tesla Model 3                76.042552
# 1                BMW i3                       75.990891
#                  Chevy Bolt                   73.637703
#                  Hyundai Kona                 74.213001
#                  Nissan Leaf                  74.953858
#                  Tesla Model 3                75.761740
# 2                BMW i3                       80.070909
#                  Chevy Bolt                   77.908433
#                  Hyundai Kona                 78.989554
#                  Nissan Leaf                  82.145861
#                  Tesla Model 3                78.297970
# 3                BMW i3                       71.091591
#                  Chevy Bolt                   66.978691
#                  Hyundai Kona                 72.407206
#                  Nissan Leaf                  70.845630
#                  Tesla Model 3                68.633597
#
#                                 Distance Driven (since last charge) (km)  \
# cluster_kpca_rbf Vehicle Model
# 0                BMW i3                                       118.237419
#                  Chevy Bolt                                   120.817593
#                  Hyundai Kona                                 128.641618
#                  Nissan Leaf                                   97.283427
#                  Tesla Model 3                                121.779977
# 1                BMW i3                                       180.577774
#                  Chevy Bolt                                   188.935418
#                  Hyundai Kona                                 192.654445
#                  Nissan Leaf                                  187.432814
#                  Tesla Model 3                                187.367074
# 2                BMW i3                                       137.872402
#                  Chevy Bolt                                   148.452506
#                  Hyundai Kona                                 165.866923
#                  Nissan Leaf                                  152.901978
#                  Tesla Model 3                                174.049915
# 3                BMW i3                                       152.355516
#                  Chevy Bolt                                   161.534901
#                  Hyundai Kona                                 158.399395
#                  Nissan Leaf                                  145.160134
#                  Tesla Model 3                                145.716197
#
#                                 Temperature (°C)  Vehicle Age (years)  \
# cluster_kpca_rbf Vehicle Model
# 0                BMW i3                18.616800             4.830653
#                  Chevy Bolt            24.330294             4.934462
#                  Hyundai Kona          20.465782             4.479570
#                  Nissan Leaf           19.268755             4.691382
#                  Tesla Model 3         20.486483             4.720711
# 1                BMW i3                11.492116             2.622817
#                  Chevy Bolt             8.504519             2.508621
#                  Hyundai Kona           9.280254             2.690004
#                  Nissan Leaf            9.911768             2.842269
#                  Tesla Model 3         11.042700             2.756062
# 2                BMW i3                 7.920873             4.194313
#                  Chevy Bolt             4.736694             4.397078
#                  Hyundai Kona           6.121151             3.735834
#                  Nissan Leaf            7.171824             3.965020
#                  Tesla Model 3          5.908874             4.006769
# 3                BMW i3                23.360506             3.458333
#                  Chevy Bolt            25.468232             2.891574
#                  Hyundai Kona          25.755676             2.871415
#                  Nissan Leaf           21.662707             3.078547
#                  Tesla Model 3         24.672336             2.997947
#
#                                 x_kpc_rbf  y_kpc_rbf  cluster_kpca_rbf
# cluster_kpca_rbf Vehicle Model
# 0                BMW i3          0.075181  -0.175211               0.0
#                  Chevy Bolt      0.063991  -0.199168               0.0
#                  Hyundai Kona    0.032130  -0.180001               0.0
#                  Nissan Leaf     0.066646  -0.168276               0.0
#                  Tesla Model 3   0.034234  -0.190178               0.0
# 1                BMW i3         -0.046904   0.181274               1.0
#                  Chevy Bolt     -0.058390   0.176403               1.0
#                  Hyundai Kona   -0.051930   0.176060               1.0
#                  Nissan Leaf    -0.036534   0.178089               1.0
#                  Tesla Model 3  -0.049409   0.177505               1.0
# 2                BMW i3         -0.189705  -0.060348               2.0
#                  Chevy Bolt     -0.206467  -0.082614               2.0
#                  Hyundai Kona   -0.212665  -0.031298               2.0
#                  Nissan Leaf    -0.210031  -0.068129               2.0
#                  Tesla Model 3  -0.202417  -0.052992               2.0
# 3                BMW i3          0.187798   0.051245               3.0
#                  Chevy Bolt      0.195986   0.059905               3.0
#                  Hyundai Kona    0.195395   0.050506               3.0
#                  Nissan Leaf     0.190401   0.045489               3.0
#                  Tesla Model 3   0.200764   0.045876               3.0

# %%
df.groupby(['cluster_kpca_rbf', 'Vehicle Model', 'Charging Station Location'])[features].mean()
# Out:
# C:\Users\MHD\AppData\Local\Temp\ipykernel_9500\3001975039.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['cluster_kpca_rbf', 'Vehicle Model', 'Charging Station Location'])[features].mean()
#                                                           Battery Capacity (kWh)  \
# cluster_kpca_rbf Vehicle Model Charging Station Location
# 0                BMW i3        Chicago                                 73.358924
#                                Houston                                 63.798044
#                                Los Angeles                             64.901706
#                                New York                                77.941836
#                                San Francisco                           68.468836
# ...                                                                          ...
# 3                Tesla Model 3 Chicago                                 63.669787
#                                Houston                                 66.129742
#                                Los Angeles                             71.752152
#                                New York                                75.864549
#                                San Francisco                           74.400000
#
#                                                           Energy Consumed (kWh)  \
# cluster_kpca_rbf Vehicle Model Charging Station Location
# 0                BMW i3        Chicago                                44.315256
#                                Houston                                44.951667
#                                Los Angeles                            44.165694
#                                New York                               53.211974
#                                San Francisco                          44.912015
# ...                                                                         ...
# 3                Tesla Model 3 Chicago                                31.243948
#                                Houston                                24.897528
#                                Los Angeles                            25.479788
#                                New York                               34.309688
#                                San Francisco                          25.939421
#
#                                                           Charging Duration (hours)  \
# cluster_kpca_rbf Vehicle Model Charging Station Location
# 0                BMW i3        Chicago                                     2.312671
#                                Houston                                     2.230921
#                                Los Angeles                                 1.994736
#                                New York                                    2.089623
#                                San Francisco                               2.408266
# ...                                                                             ...
# 3                Tesla Model 3 Chicago                                     1.752820
#                                Houston                                     1.400259
#                                Los Angeles                                 1.567537
#                                New York                                    1.524148
#                                San Francisco                               1.969632
#
#                                                           Charging Rate (kW)  \
# cluster_kpca_rbf Vehicle Model Charging Station Location
# 0                BMW i3        Chicago                             20.255597
#                                Houston                             22.117890
#                                Los Angeles                         18.106484
#                                New York                            19.193231
#                                San Francisco                       18.740395
# ...                                                                      ...
# 3                Tesla Model 3 Chicago                             29.826661
#                                Houston                             24.328737
#                                Los Angeles                         31.849784
#                                New York                            25.504955
#                                San Francisco                       29.108980
#
#                                                           Charging Cost (USD)  \
# cluster_kpca_rbf Vehicle Model Charging Station Location
# 0                BMW i3        Chicago                              24.076861
#                                Houston                              24.567292
#                                Los Angeles                          20.203146
#                                New York                             23.268093
#                                San Francisco                        24.016731
# ...                                                                       ...
# 3                Tesla Model 3 Chicago                              28.201122
#                                Houston                              27.735766
#                                Los Angeles                          25.845586
#                                New York                             26.138078
#                                San Francisco                        30.975705
#
#                                                           State of Charge (Start %)  \
# cluster_kpca_rbf Vehicle Model Charging Station Location
# 0                BMW i3        Chicago                                    59.123946
#                                Houston                                    74.746117
#                                Los Angeles                                71.235266
#                                New York                                   68.975836
#                                San Francisco                              67.254638
# ...                                                                             ...
# 3                Tesla Model 3 Chicago                                    42.176361
#                                Houston                                    63.772448
#                                Los Angeles                                60.806120
#                                New York                                   53.048273
#                                San Francisco                              53.364396
#
#                                                           State of Charge (End %)  \
# cluster_kpca_rbf Vehicle Model Charging Station Location
# 0                BMW i3        Chicago                                  72.556707
#                                Houston                                  75.469157
#                                Los Angeles                              73.421300
#                                New York                                 74.251226
#                                San Francisco                            66.989940
# ...                                                                           ...
# 3                Tesla Model 3 Chicago                                  68.270742
#                                Houston                                  72.682183
#                                Los Angeles                              63.147750
#                                New York                                 67.876551
#                                San Francisco                            74.627410
#
#                                                           Distance Driven (since last charge) (km)  \
# cluster_kpca_rbf Vehicle Model Charging Station Location
# 0                BMW i3        Chicago                                                  148.949103
#                                Houston                                                   90.217541
#                                Los Angeles                                              116.984978
#                                New York                                                 159.521792
#                                San Francisco                                             96.088402
# ...                                                                                            ...
# 3                Tesla Model 3 Chicago                                                  139.989127
#                                Houston                                                  148.921472
#                                Los Angeles                                              128.185455
#                                New York                                                 166.401716
#                                San Francisco                                            157.640312
#
#                                                           Temperature (°C)  \
# cluster_kpca_rbf Vehicle Model Charging Station Location
# 0                BMW i3        Chicago                           17.405153
#                                Houston                           12.860108
#                                Los Angeles                       17.519184
#                                New York                          22.845352
#                                San Francisco                     26.189588
# ...                                                                    ...
# 3                Tesla Model 3 Chicago                           23.610224
#                                Houston                           25.413782
#                                Los Angeles                       20.885880
#                                New York                          28.306439
#                                San Francisco                     27.842073
#
#                                                           Vehicle Age (years)  \
# cluster_kpca_rbf Vehicle Model Charging Station Location
# 0                BMW i3        Chicago                               5.481380
#                                Houston                               5.294118
#                                Los Angeles                           3.971460
#                                New York                              4.588959
#                                San Francisco                         4.846154
# ...                                                                       ...
# 3                Tesla Model 3 Chicago                               3.547554
#                                Houston                               3.600000
#                                Los Angeles                           2.437500
#                                New York                              2.700000
#                                San Francisco                         2.821103
#
#                                                           x_kpc_rbf  \
# cluster_kpca_rbf Vehicle Model Charging Station Location
# 0                BMW i3        Chicago                     0.031488
#                                Houston                     0.079687
#                                Los Angeles                 0.079280
#                                New York                    0.058542
#                                San Francisco               0.117862
# ...                                                             ...
# 3                Tesla Model 3 Chicago                     0.175892
#                                Houston                     0.250260
#                                Los Angeles                 0.205308
#                                New York                    0.174442
#                                San Francisco               0.205143
#
#                                                           y_kpc_rbf  \
# cluster_kpca_rbf Vehicle Model Charging Station Location
# 0                BMW i3        Chicago                    -0.142160
#                                Houston                    -0.207356
#                                Los Angeles                -0.169076
#                                New York                   -0.146513
#                                San Francisco              -0.191907
# ...                                                             ...
# 3                Tesla Model 3 Chicago                     0.047847
#                                Houston                    -0.029475
#                                Los Angeles                 0.073989
#                                New York                    0.044997
#                                San Francisco               0.074369
#
#                                                           cluster_kpca_rbf
# cluster_kpca_rbf Vehicle Model Charging Station Location
# 0                BMW i3        Chicago                                 0.0
#                                Houston                                 0.0
#                                Los Angeles                             0.0
#                                New York                                0.0
#                                San Francisco                           0.0
# ...                                                                    ...
# 3                Tesla Model 3 Chicago                                 3.0
#                                Houston                                 3.0
#                                Los Angeles                             3.0
#                                New York                                3.0
#                                San Francisco                           3.0
#
# [100 rows x 13 columns]

# %%
cluster_stats=df.groupby(['cluster_kpca_rbf'])[features].mean()
# Out:
# C:\Users\MHD\AppData\Local\Temp\ipykernel_9500\2792296095.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   cluster_stats=df.groupby(['cluster_kpca_rbf'])[features].mean()

# %%
for i in range(len(cluster_stats)):
    print(f"Cluster {i}:")
    print(f"- Distance moyenne parcourue depuis la dernière charge: {cluster_stats['Distance Driven (since last charge) (km)'][i]:.2f} kWh")
    print(f"- Age moyen de la vehicule: {cluster_stats['Vehicle Age (years)'][i]:.2f} years")
    print(f"- Energie moyenne consomée: {cluster_stats['Energy Consumed (kWh)'][i]:.2f} kWh")
    print(f"- Capacité moyenne de batterie: {cluster_stats['Battery Capacity (kWh)'][i]:.2f} kWh")
    print(f"- Durée moyenne de charge: {cluster_stats['Charging Duration (hours)'][i]:.2f} heures")
    print(f"- Coût moyen de la charge: {cluster_stats['Charging Cost (USD)'][i]:.2f} USD")
    print()
# Out:
# Cluster 0:
# - Distance moyenne parcourue depuis la dernière charge: 117.97 kWh
# - Age moyen de la vehicule: 4.72 years
# - Energie moyenne consomée: 50.04 kWh
# - Capacité moyenne de batterie: 68.75 kWh
# - Durée moyenne de charge: 2.21 heures
# - Coût moyen de la charge: 23.09 USD
#
# Cluster 1:
# - Distance moyenne parcourue depuis la dernière charge: 187.42 kWh
# - Age moyen de la vehicule: 2.68 years
# - Energie moyenne consomée: 33.92 kWh
# - Capacité moyenne de batterie: 81.49 kWh
# - Durée moyenne de charge: 2.24 heures
# - Coût moyen de la charge: 21.72 USD
#
# Cluster 2:
# - Distance moyenne parcourue depuis la dernière charge: 155.21 kWh
# - Age moyen de la vehicule: 4.08 years
# - Energie moyenne consomée: 56.69 kWh
# - Capacité moyenne de batterie: 76.22 kWh
# - Durée moyenne de charge: 2.80 heures
# - Coût moyen de la charge: 16.52 USD
#
# Cluster 3:
# - Distance moyenne parcourue depuis la dernière charge: 152.14 kWh
# - Age moyen de la vehicule: 3.04 years
# - Energie moyenne consomée: 30.19 kWh
# - Capacité moyenne de batterie: 70.44 kWh
# - Durée moyenne de charge: 1.77 heures
# - Coût moyen de la charge: 28.29 USD

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Liste des clusters et des colonnes à comparer
categories = ['Cluster 1', 'Cluster 2', 'Cluster 3', 'Cluster 4']

# Extraire les valeurs des statistiques moyennes pour chaque métrique
distance_driven = cluster_stats['Distance Driven (since last charge) (km)']
vehicle_age = cluster_stats['Vehicle Age (years)']
energy_consumed = cluster_stats['Energy Consumed (kWh)']
battery_capacity = cluster_stats['Battery Capacity (kWh)']
charging_duration = cluster_stats['Charging Duration (hours)']
charging_cost = cluster_stats['Charging Cost (USD)']

# Créer la figure avec 3 lignes et 2 colonnes pour accueillir 6 sous-graphes
fig, axes = plt.subplots(3, 2, figsize=(14, 15))

# Premier graphique : Distance Driven (since last charge) (km)
sns.barplot(x=categories, y=distance_driven, ax=axes[0, 0])
axes[0, 0].set_title('Distance parcourue depuis la dernière charge (km)')

# Deuxième graphique : Vehicle Age (years)
sns.barplot(x=categories, y=vehicle_age, ax=axes[0, 1])
axes[0, 1].set_title('Âge du véhicule (years)')

# Troisième graphique : Energy Consumed (kWh)
sns.barplot(x=categories, y=energy_consumed, ax=axes[1, 0])
axes[1, 0].set_title('Énergie consommée (kWh)')

# Quatrième graphique : Battery Capacity (kWh)
sns.barplot(x=categories, y=battery_capacity, ax=axes[1, 1])
axes[1, 1].set_title('Capacité de la batterie (kWh)')

# Cinquième graphique : Charging Cost (USD)
sns.barplot(x=categories, y=charging_cost, ax=axes[2, 0])
axes[2, 0].set_title('Coût de la charge (USD)')

# Sixième graphique : Charging Duration (hours)
sns.barplot(x=categories, y=charging_duration, ax=axes[2, 1])
axes[2, 1].set_title('Durée de charge (heures)')

# Ajuster l'espacement entre les sous-graphes
plt.tight_layout()

# Afficher le graphique
plt.show()

# %%
import seaborn as sns

# Visualiser la distribution de la capacité de la batterie dans chaque cluster
plt.figure(figsize=(10, 6))
sns.boxplot(x='cluster_kpca_rbf', y='Battery Capacity (kWh)', data=df)
plt.title('Distribution de la capacité de la batterie par cluster')
plt.show()
